# %%
#importar biblioteca Pandas#
import pandas as pd
import matplotlib.pyplot as plt
low_memory=False
# %matplotlib inline

# %%
#importar banco de dados - Mulheres convivendo com HIV entre 24 e 49 anos#
filename = r'C:\Users\guita\HIV_mulher.csv'
df = pd.read_csv(filename, delimiter=',', 
                 encoding='ISO-8859-1',
                 error_bad_lines=False)

# %%
#Verificar a quantidade de colunas e linhas#
df.shape
# Out:
# (171, 91)

# %%
#Descrição dos Dados#
df.describe()
# Out:
#                1990    1990_lower    1990_upper          1991    1991_lower  \
# count  5.600000e+01  5.300000e+01  6.500000e+01  6.100000e+01  5.600000e+01
# mean   1.058411e+05  9.086415e+04  1.114092e+05  1.212475e+05  1.091286e+05
# std    4.030509e+05  3.457495e+05  4.492287e+05  4.890060e+05  4.300700e+05
# min    1.100000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.100000e+03
# 25%    3.750000e+03  3.000000e+03  4.500000e+03  4.200000e+03  3.350000e+03
# 50%    1.550000e+04  1.200000e+04  1.900000e+04  1.600000e+04  1.350000e+04
# 75%    5.050000e+04  3.300000e+04  6.400000e+04  5.500000e+04  4.400000e+04
# max    3.000000e+06  2.500000e+06  3.600000e+06  3.800000e+06  3.200000e+06
#
#          1991_upper          1992    1992_lower    1992_upper          1993  \
# count  7.000000e+01  6.800000e+01  5.900000e+01  7.300000e+01  7.000000e+01
# mean   1.263414e+05  1.313279e+05  1.241136e+05  1.470000e+05  1.500700e+05
# ...

# %%
#Obter as informações dos dados#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 91 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     171 non-null    object
#  1   1990        56 non-null     float64
#  2   1990_lower  53 non-null     float64
#  3   1990_upper  65 non-null     float64
#  4   1991        61 non-null     float64
#  5   1991_lower  56 non-null     float64
#  6   1991_upper  70 non-null     float64
#  7   1992        68 non-null     float64
#  8   1992_lower  59 non-null     float64
#  9   1992_upper  73 non-null     float64
#  10  1993        70 non-null     float64
#  11  1993_lower  63 non-null     float64
#  12  1993_upper  77 non-null     float64
#  13  1994        73 non-null     float64
#  14  1994_lower  66 non-null     float64
#  15  1994_upper  77 non-null     float64
#  16  1995        74 non-null     float64
#  17  1995_lower  67 non-null     float64
# ...

# %%
#Amostra de como os dados estão distribuídos na tabela#
df.sample(5)
# Out:
#                       Country      1990  1990_lower  1990_upper      1991  \
# 66                     Guinea   12000.0      6800.0     21000.0   15000.0
# 161  UnitedRepublicofTanzania  220000.0    190000.0    240000.0  260000.0
# 53                    Estonia       NaN         NaN         NaN       NaN
# 48                    Ecuador    2500.0         NaN      5600.0    3000.0
# 89                    Lesotho   16000.0     12000.0     21000.0   23000.0
#
#      1991_lower  1991_upper      1992  1992_lower  1992_upper  ...  \
# 66       8800.0     23000.0   18000.0     11000.0     28000.0  ...
# 161    240000.0    290000.0  310000.0    290000.0    350000.0  ...
# 53          NaN         NaN       NaN         NaN         NaN  ...
# 48          NaN      6500.0    3400.0      1100.0      7000.0  ...
# 89      18000.0     29000.0   33000.0     27000.0     39000.0  ...
#
#      2016_upper      2017  2017_lower  2017_upper      2018  2018_lower  \
# ...

# %%
#Transformar a coluna Country como um dos índices para futuras análises#
df.set_index('Country', inplace=True)

# %%
df
# Out:
#                   1990  1990_lower  1990_upper       1991  1991_lower  \
# Country
# Afghanistan        NaN         NaN         NaN        NaN         NaN
# Albania            NaN         NaN         NaN        NaN         NaN
# Algeria            NaN         NaN         NaN        NaN         NaN
# Angola          5800.0      3300.0     11000.0     7500.0      4500.0
# Argentina       3600.0      3000.0      4500.0     4800.0      4200.0
# ...                ...         ...         ...        ...         ...
# VietNam            NaN         NaN         NaN        NaN         NaN
# Yemen              NaN         NaN         NaN        NaN         NaN
# Zambia        150000.0    140000.0    150000.0   180000.0    170000.0
# Zimbabwe      320000.0    280000.0    360000.0   400000.0    350000.0
# Global       3000000.0   2500000.0   3600000.0  3800000.0   3200000.0
#
#              1991_upper       1992  1992_lower  1992_upper       1993  ...  \
# ...

# %%
#excluir as colunas contendo _upper e _lower pois são valores máximos e mínimos que não nos interessa#
df = df.drop(['1990_lower','1990_upper','1991_lower','1991_upper','1992_lower','1992_upper','1993_lower','1993_upper','1994_lower','1994_upper','1995_lower','1995_upper','1996_lower','1996_upper','1997_lower','1997_upper','1998_lower','1998_upper','1999_lower','1999_upper','2000_lower','2000_upper','2001_lower','2001_upper','2002_lower','2002_upper','2003_lower','2003_upper','2004_lower','2004_upper','2005_lower','2005_upper','2006_lower','2006_upper','2007_lower','2007_upper','2008_lower','2008_upper','2009_lower','2009_upper','2010_lower','2010_upper','2011_lower','2011_upper','2012_lower','2012_upper','2013_lower','2013_upper','2014_lower','2014_upper','2015_lower','2015_upper','2016_lower','2016_upper','2017_lower','2017_upper','2018_lower','2018_upper','2019_lower','2019_upper',], axis = 1)

# %%
df
# Out:
#                   1990       1991       1992       1993       1994       1995  \
# Country
# Afghanistan        NaN        NaN        NaN        NaN        NaN        NaN
# Albania            NaN        NaN        NaN        NaN        NaN        NaN
# Algeria            NaN        NaN        NaN        NaN        NaN        NaN
# Angola          5800.0     7500.0     9500.0    12000.0    15000.0    18000.0
# Argentina       3600.0     4800.0     6200.0     7700.0     9100.0    10000.0
# ...                ...        ...        ...        ...        ...        ...
# VietNam            NaN        NaN     1900.0     3700.0     6600.0    10000.0
# Yemen              NaN        NaN        NaN        NaN        NaN        NaN
# Zambia        150000.0   180000.0   210000.0   240000.0   270000.0   300000.0
# Zimbabwe      320000.0   400000.0   490000.0   560000.0   610000.0   660000.0
# Global       3000000.0  3800000.0  4600000.0  5400000.0  6300000.0  7100000.0
#
# ...

# %%
#Vamos eliminar todos as linhas que não possuem valores numéricos (NaN) pois não é nosso interesse utilizar esse tipo de dado#
df = df.dropna()

# %%
df = df.transpose()

# %%
df
# Out:
# Country    Angola  Argentina    Benin  Bolivia(PlurinationalStateof)  \
# 1990       5800.0     3600.0   1700.0                         3500.0
# 1991       7500.0     4800.0   2800.0                         4200.0
# 1992       9500.0     6200.0   4500.0                         5000.0
# 1993      12000.0     7700.0   6700.0                         5700.0
# 1994      15000.0     9100.0   9200.0                         6300.0
# 1995      18000.0    10000.0  12000.0                         6700.0
# 1996      22000.0    12000.0  15000.0                         7100.0
# 1997      26000.0    13000.0  17000.0                         7300.0
# 1998      31000.0    14000.0  19000.0                         7300.0
# 1999      36000.0    15000.0  21000.0                         7200.0
# 2000      42000.0    16000.0  23000.0                         7000.0
# 2001      49000.0    17000.0  24000.0                         6700.0
# 2002      56000.0    18000.0  25000.0                         6300.0
# ...

# %%
df.loc['1998']
# Out:
# Country
# Angola                               31000.0
# Argentina                            14000.0
# Benin                                19000.0
# Bolivia(PlurinationalStateof)         7300.0
# Botswana                            120000.0
# Brazil                              120000.0
# BurkinaFaso                          61000.0
# Burundi                              57000.0
# Cameroon                            170000.0
# CentralAfricanRepublic               68000.0
# Chad                                 38000.0
# Colombia                             23000.0
# Congo                                41000.0
# CÃ´ted'Ivoire                       280000.0
# DemocraticRepublicoftheCongo        310000.0
# DominicanRepublic                    39000.0
# Ecuador                               5600.0
# Eritrea                               7800.0
# Eswatini                             53000.0
# Ethiopia                            420000.0
# Gabon                                15000.0
# ...

# %%
df.loc['1998','Brazil']
# Out:
# 120000.0

# %%
df.loc['2019','Brazil']
# Out:
# 220000.0

# %%
df.reset_index(level=0, inplace=True)

# %%
df
# Out:
# Country index    Angola  Argentina    Benin  Bolivia(PlurinationalStateof)  \
# 0        1990    5800.0     3600.0   1700.0                         3500.0
# 1        1991    7500.0     4800.0   2800.0                         4200.0
# 2        1992    9500.0     6200.0   4500.0                         5000.0
# 3        1993   12000.0     7700.0   6700.0                         5700.0
# 4        1994   15000.0     9100.0   9200.0                         6300.0
# 5        1995   18000.0    10000.0  12000.0                         6700.0
# 6        1996   22000.0    12000.0  15000.0                         7100.0
# 7        1997   26000.0    13000.0  17000.0                         7300.0
# 8        1998   31000.0    14000.0  19000.0                         7300.0
# 9        1999   36000.0    15000.0  21000.0                         7200.0
# 10       2000   42000.0    16000.0  23000.0                         7000.0
# ...

# %%
df = df.rename(columns={'index': 'Ano'})

# %%
df
# Out:
# Country   Ano    Angola  Argentina    Benin  Bolivia(PlurinationalStateof)  \
# 0        1990    5800.0     3600.0   1700.0                         3500.0
# 1        1991    7500.0     4800.0   2800.0                         4200.0
# 2        1992    9500.0     6200.0   4500.0                         5000.0
# 3        1993   12000.0     7700.0   6700.0                         5700.0
# 4        1994   15000.0     9100.0   9200.0                         6300.0
# 5        1995   18000.0    10000.0  12000.0                         6700.0
# 6        1996   22000.0    12000.0  15000.0                         7100.0
# 7        1997   26000.0    13000.0  17000.0                         7300.0
# 8        1998   31000.0    14000.0  19000.0                         7300.0
# 9        1999   36000.0    15000.0  21000.0                         7200.0
# 10       2000   42000.0    16000.0  23000.0                         7000.0
# ...

# %%
colunas_selecionadas = ['Ano','Brazil']

# %%
AnoBrazil = df.filter(items=colunas_selecionadas)

# %%
AnoBrazil.head()
# Out:
# Country   Ano   Brazil
# 0        1990  44000.0
# 1        1991  53000.0
# 2        1992  62000.0
# 3        1993  70000.0
# 4        1994  79000.0

# %%
AnoBrazil.plot('Ano','Brazil')

# %%
df.plot('Ano','Argentina')

# %%
df.plot('Ano','Angola')

# %%
df.plot('Ano','Global')

# %%
df.plot.scatter('Ano','Brazil')

# %%
df.plot.bar('Ano','Brazil')

# %%
colunas_AmericaLatina = ['Ano','Brazil','Bolivia(PlurinationalStateof)','Venezuela(BolivarianRepublicof)','Argentina','Bolivia','Colombia','Ecuador','Peru']

# %%
AmericaLatina = df.filter(items=colunas_AmericaLatina)

# %%
AmericaLatina.head()
# Out:
# Country   Ano   Brazil  Bolivia(PlurinationalStateof)  \
# 0        1990  44000.0                         3500.0
# 1        1991  53000.0                         4200.0
# 2        1992  62000.0                         5000.0
# 3        1993  70000.0                         5700.0
# 4        1994  79000.0                         6300.0
#
# Country  Venezuela(BolivarianRepublicof)  Argentina  Colombia  Ecuador    Peru
# 0                                 4500.0     3600.0    5200.0   2500.0  3800.0
# 1                                 5200.0     4800.0    7500.0   3000.0  4200.0
# 2                                 6000.0     6200.0   10000.0   3400.0  4700.0
# 3                                 6800.0     7700.0   13000.0   3900.0  5300.0
# 4                                 7900.0     9100.0   16000.0   4300.0  5900.0

# %%
AmericaLatina.set_index('Ano', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-161c556000c4> in <module>
# ----> 1 AmericaLatina.set_index('Ano', inplace=True)
#
# c:\users\guita\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Ano'] are in the columns"

# %%
AmericaLatina.head()
# Out:
# Country   Brazil  Bolivia(PlurinationalStateof)  \
# Ano
# 1990     44000.0                         3500.0
# 1991     53000.0                         4200.0
# 1992     62000.0                         5000.0
# 1993     70000.0                         5700.0
# 1994     79000.0                         6300.0
#
# Country  Venezuela(BolivarianRepublicof)  Argentina  Colombia  Ecuador    Peru
# Ano
# 1990                              4500.0     3600.0    5200.0   2500.0  3800.0
# 1991                              5200.0     4800.0    7500.0   3000.0  4200.0
# 1992                              6000.0     6200.0   10000.0   3400.0  4700.0
# 1993                              6800.0     7700.0   13000.0   3900.0  5300.0
# 1994                              7900.0     9100.0   16000.0   4300.0  5900.0

# %%
AmericaLatina.min()
# Out:
# Country
# Brazil                             44000.0
# Bolivia(PlurinationalStateof)       3500.0
# Venezuela(BolivarianRepublicof)     4500.0
# Argentina                           3600.0
# Colombia                            5200.0
# Ecuador                             2500.0
# Peru                                3800.0
# dtype: float64

# %%
#Como podemos ver através dos dados. Desde o início, o Brazil é o país com maior número de mulheres infectadas por HIV com 44 mil mulheres.#

# %%
AmericaLatina.max()
# Out:
# Country
# Brazil                             220000.0
# Bolivia(PlurinationalStateof)        7300.0
# Venezuela(BolivarianRepublicof)     48000.0
# Argentina                           29000.0
# Colombia                            36000.0
# Ecuador                             11000.0
# Peru                                15000.0
# dtype: float64

# %%
AmericaLatina.mean()
# Out:
# Country
# Brazil                             161066.666667
# Bolivia(PlurinationalStateof)        5103.333333
# Venezuela(BolivarianRepublicof)     29383.333333
# Argentina                           18813.333333
# Colombia                            23123.333333
# Ecuador                              6883.333333
# Peru                                 9903.333333
# dtype: float64

# %%
AmericaLatina.plot.bar()

# %%
AmericaLatina.plot.line()
